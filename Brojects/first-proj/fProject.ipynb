# %% [markdown]
# ### wellcom first project.

# %%
### over view project to learn

# %% [markdown]
# #### we show every steps of data analysis

# %% [markdown]
# #### 1=> import libraries and modules

# %%
import pandas as pd # help me to import dataset

# %% [markdown]
# #### 2 => import my data (wrangle)

# %%
ecom = pd.read_csv('1.1 ecommerce-purchases.csv')

# %%
ecom ## this to display my data | use head()
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
#     => info function --> give info about your data.
#      like : [colums-name , number of records , type of data,....]

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 3=> data preprocessing (i process my data)
#       - like [search for null value | search form missing value | duplicated value]

# %%
ecom.isnull().sum() # i used sum to give me all values.
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
ecom.duplicated().sum() # to find all duplicated value.
# Out:
# np.int64(0)

# %%
ecom.rename(columns={'Credit Card' : 'Credit_Card'}) # use it to => rename a colums name (one of preprocessing data)
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
#     ##### => conver  the language colum to UpperCases.

# %%
ecom['Language'].str.upper()
# Out:
# 0       EL
# 1       FR
# 2       DE
# 3       ES
# 4       ES
#         ..
# 9995    IT
# 9996    PT
# 9997    EL
# 9998    ES
# 9999    EL
# Name: Language, Length: 10000, dtype: object

# %% [markdown]
# ### 4 - analysis Data

# %% [markdown]
#     -> Data Exploration (EDA):
#         - im search For :
#             + patterns
#             + RelationShip (bettwen my data | values)
#         ----------------------------------------------
#         => i have data , what is the question i asked it to know my data.
#             ==> go back , explore your data.
#         ----------------------------------------------
#         $=> what i found:
#             + what is the average price.
#             + what is the language of user in website.
#             + what is the jop of most client used me website.
#             + type of the browser.
#             + what is the time , which get the bigest vist.
#             + know the counter of users.

# %%
ecom['Purchase Price'].mean() # price average
# Out:
# np.float64(50.347302)

# %%
ecom['Purchase Price'].max() #highest value in prince
# Out:
# np.float64(99.99)

# %%
ecom['Purchase Price'].min() #lowest value in prince
# Out:
# np.float64(0.0)

# %% [markdown]
# ##### how many pepole there lang en

# %%
ecom[ecom['Language'] == 'en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %% [markdown]
# #### <> how many pepole has the jop title 'Lawyer'

# %%
ecom[ecom['Job'] == 'Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %% [markdown]
# #### how many pepole made the purchase during AM and PM

# %%
ecom['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# #### => what are the 5 most common jop Title?:

# %%
ecom['Job'].value_counts().head()
# Out:
# Job
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Research officer, political party    27
# Designer, jewellery                  27
# Name: count, dtype: int64

# %% [markdown]
# #### how many pepole have American Express as Cridet card , and made a pruchase above 95 USD ?

# %%
ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] >= 95)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...  80 zh       PM
# 372              359 Stanley Coves\nSalasfort, SD 59457  75 Ub       PM
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766             386 Alisha Unions\nSteelebury, ND 19782  28 pJ       PM
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...  45 MR       PM
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...  06 ia       PM
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...  94 qM       AM
# 2146           557 Barton Harbor\nFuentesport, VI 29961  96 MV       AM
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341  52 WA       AM
# ...

# %% [markdown]
# ### visualization

# %% [markdown]
# #### plot summary statistics of the -> Purchase Price <-

# %%
ecom['Purchase Price'].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# #### plot the count of each customer's 'Language' regarding their 12-hours clock

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
sns.countplot(x=ecom['Language'] , hue=ecom['AM or PM'])
# Out:
# <Axes: xlabel='Language', ylabel='count'>
